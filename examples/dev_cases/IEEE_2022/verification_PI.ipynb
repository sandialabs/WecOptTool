# %% [markdown]
# # Linear Frequency-Dependent PTO

# %%
import os
import logging

import matplotlib.pyplot as plt
import capytaine as cpy
from autograd.builtins import isinstance, tuple, list, dict
import autograd.numpy as np
import xarray as xr

import wecopttool as wot


# logging 
logging.basicConfig(level=logging.INFO)

# create save directory
results_dir = 'results_linear_freqdep_pto'
if not os.path.exists(results_dir):
  os.makedirs(results_dir)

# frequencies
f0 = 0.05
nfreq = 50

# %% [markdown]
# ### WEC

# %%
## WEC object
# mesh
wb = wot.geom.WaveBot() 
mesh_size_factor = 0.5 
mesh = wb.mesh(mesh_size_factor)

# floating body
fb = cpy.FloatingBody.from_meshio(mesh, name="WaveBot")
fb.add_translation_dof(name="HEAVE")

# hydrostatics
hs_data = wot.hydrostatics.hydrostatics(fb)
mass_33 = wot.hydrostatics.mass_matrix_constant_density(hs_data)[2, 2]
mass = np.atleast_2d(mass_33)
stiffness_33 = wot.hydrostatics.stiffness_matrix(hs_data)[2, 2]
stiffness = np.atleast_2d(stiffness_33)

# WEC object
wec = wot.WEC(fb, mass, stiffness, f0, nfreq)

# BEM
fname = os.path.join(results_dir, 'bem.nc')
if os.path.exists(fname):
    wec.read_bem(fname)
else:
    wec.run_bem()
    wec.write_bem(fname)
# Out:
# INFO:capytaine.bodies.bodies:Stored 1054 triangle faces as quadrilaterals
# INFO:capytaine.bodies.bodies:New floating body: WaveBot.
# INFO:wecopttool.core:Changing value of 'f_add'. This might cause some attributes to be reset.
# INFO:wecopttool.core:New WEC: WaveBot with 1 DOF.
# INFO:wecopttool.core:Reading BEM data from results_linear_freqdep_pto/bem.nc.
# INFO:wecopttool.core:Impedance matrix deleted. To calculate impedance call 'self.bem_calc_impedance()'
# INFO:wecopttool.core:Impedance matrix deleted. To calculate impedance call 'self.bem_calc_impedance()'
# INFO:wecopttool.core:Calculating impedance matrix.
# INFO:capytaine.post_pro.impedance:Compute impedance.
# WARNING:wecopttool.core:Linear damping for DOF "HEAVE" has negative or close to zero terms. Shifting up.

# %% [markdown]
# ### PTO

# %%
# PTO kinematics
kinematics = np.eye(fb.nb_dofs)

# PTO impedance - frequency dependent
gear_ratio = 12.0
torque_constant = 6.7
winding_resistance = 0.5
winding_inductance = 0.0
drivetrain_inertia = 2.0 
drivetrain_friction = 1.0
drivetrain_stiffness = 0.0

drivetrain_impedance = (1j*wec.omega*drivetrain_inertia + 
                        drivetrain_friction + 
                        -1/(1j*wec.omega)*drivetrain_stiffness) 

winding_impedance = winding_resistance + 1j*wec.omega*winding_inductance

pto_impedance_11 = gear_ratio**2 * drivetrain_impedance
off_diag = np.sqrt(3.0/2.0) * torque_constant * gear_ratio
pto_impedance_12 = (off_diag+0j) * np.ones(wec.omega.shape) 
pto_impedance_21 = pto_impedance_12
pto_impedance_22 = winding_impedance
pto_impedance = np.array([[pto_impedance_11, pto_impedance_12],
                          [pto_impedance_21, pto_impedance_22]])

# create PTO
pto = wot.pto.PILinearPTO(nfreq, kinematics, pto_impedance)

# add PTO force to WEC
wec.f_add = pto.force_on_wec
# Out:
# INFO:wecopttool.core:Changing value of 'f_add'. This might cause some attributes to be reset.

# %% [markdown]
# ### Waves

# %%
# waves
wfreq = 0.3
amplitude = 0.0625
phase = -40
waves = wot.waves.regular_wave(f0, nfreq, wfreq, amplitude, phase)

# %% [markdown]
# ### Objective Function

# %%
# objective function
obj_fun = pto.electric_average_power
nstate_opt = pto.nstate

# %% [markdown]
# ### Solve

# %%
# solve
scale_x_wec = 1.0
scale_x_opt = 0.001
scale_obj = 1.0

options = {'maxiter': 100, 'ftol': 1e-8}

wec_tdom, wec_fdom, x_wec, x_opt, obj, res = wec.solve(
    waves, obj_fun, nstate_opt, optim_options=options,
    scale_x_wec=scale_x_wec, scale_x_opt=scale_x_opt, scale_obj=scale_obj)

# post-process
pto_tdom, pto_fdom = pto.post_process(wec, x_wec, x_opt)
# Out:
# INFO:wecopttool.core:Solving pseudo-spectral control problem.
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.04e+03, 4.95e+05, 9.70e+26]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.32e+03, 3.90e+05, 1.71e+26]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.80e+02, 1.06e+05, 2.42e+21]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.65e+02, 2.37e+05, 3.54e+22]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.78e+01, 7.55e+03, 4.83e+16]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.24e-02, 2.74e+01, 9.31e+04]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [5.30e-02, 8.55e+00, 9.41e+07]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [5.15e-03, 2.21e+01, 1.21e+04]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.32e-04, 2.18e+01, 5.99e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.49e-04, 2.18e+01, 1.30e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.30e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.30e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.30e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.30e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.30e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.30e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.29e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.18e+01, 1.29e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.50e-04, 2.17e+01, 1.29e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.54e-04, 2.13e+01, 1.27e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.71e-04, 1.94e+01, 1.16e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.08e-04, 5.59e+00, 1.09e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.44e-04, 1.24e+01, 5.77e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.28e-04, 1.67e+00, 5.58e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [8.19e-04, 8.05e-01, 1.17e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [8.60e-04, 1.30e-01, 1.21e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.04e-03, 1.90e+00, 1.19e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.07e-03, 2.02e+00, 1.22e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.02e-03, 1.48e+00, 1.34e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.00e-03, 1.30e+00, 1.35e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.01e-03, 1.32e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.01e-03, 1.32e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.01e-03, 1.33e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.01e-03, 1.34e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.01e-03, 1.35e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.01e-03, 1.37e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.01e-03, 1.40e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.02e-03, 1.45e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.03e-03, 1.54e+00, 1.36e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.04e-03, 1.68e+00, 1.37e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.06e-03, 1.89e+00, 1.39e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.08e-03, 2.21e+00, 1.45e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.08e-03, 2.61e+00, 1.62e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [9.38e-04, 2.80e+00, 2.02e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.52e-04, 2.30e+00, 2.18e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.02e-04, 1.89e+00, 2.32e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.70e-04, 1.40e+00, 2.38e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.62e-04, 1.13e+00, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.64e-04, 1.03e+00, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.66e-04, 1.02e+00, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 1.02e+00, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 1.02e+00, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 1.02e+00, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 1.02e+00, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 1.02e+00, 2.41e+01]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -24.098099023939128
#             Iterations: 55
#             Function evaluations: 84
#             Gradient evaluations: 55

# %% [markdown]
# ### Solve unstructured

# %%
# PTO
pto_ps = wot.pto.PseudoSpectralLinearPTO(nfreq, kinematics, pto_impedance)

# add PTO force to WEC
wec.f_add = pto_ps.force_on_wec

# objective function
obj_fun = pto_ps.electric_average_power
nstate_opt = pto_ps.nstate

# solve
scale_x_wec = 1.0
scale_x_opt = 0.01
scale_obj = 1.0

options = {'maxiter': 100, 'ftol': 1e-8}

_, _, x_wec_ps, x_opt_ps, _, _ = wec.solve(
    waves, obj_fun, nstate_opt, optim_options=options,
    scale_x_wec=scale_x_wec, scale_x_opt=scale_x_opt, scale_obj=scale_obj)
# Out:
# INFO:wecopttool.core:Changing value of 'f_add'. This might cause some attributes to be reset.
# INFO:wecopttool.core:Solving pseudo-spectral control problem.
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.86e-02, 1.91e+00, 3.22e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.84e-01, 2.84e+01, 8.19e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [5.77e-02, 2.91e+01, 1.81e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.09e-03, 4.82e-01, 6.71e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.59e-02, 3.92e+00, 4.70e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.04e-02, 8.79e+00, 9.76e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.18e-02, 1.36e+00, 3.87e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.95e-02, 3.46e+00, 1.17e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.34e-02, 3.85e-02, 8.85e+03]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.75e-04, 4.88e-01, 2.75e+02]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [9.70e-04, 2.59e-01, 9.70e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.12e-03, 7.44e-02, 2.17e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.33e-04, 4.13e-01, 2.38e+02]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.06e-03, 7.84e-02, 1.98e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.76e-04, 2.73e-02, 1.69e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.21e-04, 4.43e-02, 2.25e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.67e-04, 4.84e-02, 2.34e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.24e-04, 4.65e-02, 2.28e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.05e-04, 3.85e-02, 2.40e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.47e-04, 3.04e-02, 2.40e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.79e-04, 2.91e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.62e-04, 2.39e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.69e-04, 2.24e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.69e-04, 2.33e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.68e-04, 2.31e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 2.26e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 2.25e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 2.24e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 2.24e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 2.24e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 2.24e-02, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.67e-04, 2.24e-02, 2.41e+01]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -24.098099013123175
#             Iterations: 32
#             Function evaluations: 42
#             Gradient evaluations: 32

# %% [markdown]
# ### CC (Electrical) Solution

# %%
Z_11 = pto_impedance[0, 0, :]
Z_12 = pto_impedance[0, 1, :]
Z_21 = pto_impedance[1, 0, :]
Z_22 = pto_impedance[1, 1, :]

idof = 0
Fe = wec_fdom['excitation_force'][1:, idof]
Zi = wec.hydro.Zi[:, idof, idof]

V_th = Z_21 / (Z_11 - Zi) * Fe
Z_th = Z_22 - (Z_12*Z_21) / (Z_11 - Zi)

cc_current_fd = V_th / (2*Z_th.real)
cc_voltage_fd = -1.0 * Z_th.conj() * cc_current_fd

cc_current_td = wot.post_process_continuous_time(cc_current_fd)
cc_voltage_td = wot.post_process_continuous_time(cc_voltage_fd)

# %%
# Mechanical quantities
cc_velocity_fd = np.zeros(nfreq) *0j
cc_force_fd = np.zeros(nfreq) * 0j

for ifreq in range(nfreq):
    abc_inv = np.linalg.inv(pto._impedance_abc[:, :, ifreq])
    vec_elec = np.array([[cc_current_fd[ifreq]], [cc_voltage_fd[ifreq]]])
    vec_mech = abc_inv @ vec_elec
    cc_velocity_fd[ifreq] = vec_mech[0, 0]
    cc_force_fd[ifreq] = vec_mech[1, 0]

cc_velocity_fd = xr.DataArray(
    cc_velocity_fd, dims=["omega"], coords=[("omega", wec.omega),],)
cc_force_fd = xr.DataArray(
    cc_force_fd, dims=["omega"], coords=[("omega", wec.omega), ],)

cc_velocity_td = wot.post_process_continuous_time(cc_velocity_fd)
cc_force_td = wot.post_process_continuous_time(cc_force_fd)

# %% [markdown]
# ### Compare Results to CC

# %%
nsubsteps = 10
t = wec.make_time_vec(nsubsteps)

# plot electrical power
plt.figure()
plt.plot(t, cc_current_td(t), '-', label='Optimal')
plt.plot(t, pto.electric_current(
    wec, x_wec, x_opt, nsubsteps), '--', label='PI Controller')
plt.xlabel('time [s]')
plt.ylabel('current [A]')
plt.legend()

plt.figure()
plt.plot(t, cc_voltage_td(t), '-')
plt.plot(t, pto.electric_voltage(wec, x_wec, x_opt, nsubsteps), '--')
plt.xlabel('time [s]')
plt.ylabel('voltage [V]')

plt.figure()
plt.plot(t, cc_current_td(t)*cc_voltage_td(t), '-', linewidth=2, color="0.5", label='Optimal')
plt.plot(t, pto_ps.electric_power(wec, x_wec_ps, x_opt_ps, nsubsteps), '-', label='Unstructured')
plt.plot(t, pto.electric_power(wec, x_wec, x_opt, nsubsteps), '--', label='PI')
plt.xlabel('time [s]')
plt.ylabel('electrical power [W]')
plt.legend()
plt.savefig('verification_epower.pdf')

# %%
# plot mechanical power
plt.figure()
plt.plot(t, cc_velocity_td(t), '-', label='CC_e')
plt.plot(t, pto.velocity(
    wec, x_wec, x_opt, nsubsteps), '--', label='PS')
plt.xlabel('time [s]')
plt.ylabel('velocity [m/s]')
plt.legend()

plt.figure()
plt.plot(t, cc_force_td(t), '-')
plt.plot(t, pto.force(wec, x_wec, x_opt, nsubsteps), '--')
plt.xlabel('time [s]')
plt.ylabel('force [N]')

plt.figure()
plt.plot(t, cc_velocity_td(t)*cc_force_td(t), '-')
plt.plot(t, pto.power(wec, x_wec, x_opt, nsubsteps), '--')
plt.xlabel('time [s]')
plt.ylabel('mechanical power [W]')
# Out:
# Text(0, 0.5, 'mechanical power [W]')

# %% [markdown]
# ### Optimal gains

# %%
ind = int(np.where(np.isclose(wec.freq, wfreq))[0])

i_opt = cc_current_fd.values[ind]
V_opt = cc_voltage_fd.values[ind]

Z_Fu = pto.impedance[0, 0, ind]
Z_Fi = pto.impedance[0, 1, ind]
Z_Vu = pto.impedance[1, 0, ind]
Z_Vi = pto.impedance[1, 1, ind]

D_abc = Z_Vu + (Z_Vi - 1)*(Z_Fu/Z_Fi)

u_opt = -Z_Vi/D_abc * i_opt + V_opt/D_abc
F_opt = (Z_Fi - Z_Fu*Z_Vi/D_abc) * i_opt + V_opt/D_abc*Z_Fu

C_opt = F_opt / u_opt
(-np.imag(C_opt)*wec.omega[ind], np.real(C_opt))
# Out:
# (7005.571061331491, -4694.268133981681)

# %%
x_opt
# Out:
# array([ 6773.36932762, -4723.60668804])
