# %% [markdown]
# # Linear Frequency-Dependent PTO

# %%
import os
import logging

import matplotlib.pyplot as plt
import capytaine as cpy
from autograd.builtins import isinstance, tuple, list, dict
import autograd.numpy as np
import xarray as xr

import wecopttool as wot


# logging 
logging.basicConfig(level=logging.INFO)

# create save directory
results_dir = 'results_linear_freqdep_pto'
if not os.path.exists(results_dir):
  os.makedirs(results_dir)

# frequencies
f0 = 0.05
nfreq = 50

# %% [markdown]
# ### WEC

# %%
## WEC object
# mesh
wb = wot.geom.WaveBot() 
mesh_size_factor = 0.5 
mesh = wb.mesh(mesh_size_factor)

# floating body
fb = cpy.FloatingBody.from_meshio(mesh, name="WaveBot")
fb.add_translation_dof(name="HEAVE")

# hydrostatics
hs_data = wot.hydrostatics.hydrostatics(fb)
mass_33 = wot.hydrostatics.mass_matrix_constant_density(hs_data)[2, 2]
mass = np.atleast_2d(mass_33)
stiffness_33 = wot.hydrostatics.stiffness_matrix(hs_data)[2, 2]
stiffness = np.atleast_2d(stiffness_33)

# WEC object
wec = wot.WEC(fb, mass, stiffness, f0, nfreq)

# BEM
fname = os.path.join(results_dir, 'bem.nc')
if os.path.exists(fname):
    wec.read_bem(fname)
else:
    wec.run_bem()
    wec.write_bem(fname)
# Out:
# INFO:capytaine.bodies.bodies:Stored 1054 triangle faces as quadrilaterals
# INFO:capytaine.bodies.bodies:New floating body: WaveBot.
# INFO:wecopttool.core:Changing value of 'f_add'. This might cause some attributes to be reset.
# INFO:wecopttool.core:New WEC: WaveBot with 1 DOF.
# INFO:wecopttool.core:Reading BEM data from results_linear_freqdep_pto/bem.nc.
# INFO:wecopttool.core:Impedance matrix deleted. To calculate impedance call 'self.bem_calc_impedance()'
# INFO:wecopttool.core:Impedance matrix deleted. To calculate impedance call 'self.bem_calc_impedance()'
# INFO:wecopttool.core:Calculating impedance matrix.
# INFO:capytaine.post_pro.impedance:Compute impedance.
# WARNING:wecopttool.core:Linear damping for DOF "HEAVE" has negative or close to zero terms. Shifting up.

# %% [markdown]
# ### PTO

# %%
# PTO kinematics
kinematics = np.eye(fb.nb_dofs)

# PTO impedance - frequency dependent
gear_ratio = 12.0
torque_constant = 6.7
winding_resistance = 0.5
winding_inductance = 0.0
drivetrain_inertia = 2.0 
drivetrain_friction = 1.0
drivetrain_stiffness = 0.0

drivetrain_impedance = (1j*wec.omega*drivetrain_inertia + 
                        drivetrain_friction + 
                        -1/(1j*wec.omega)*drivetrain_stiffness) 

winding_impedance = winding_resistance + 1j*wec.omega*winding_inductance

pto_impedance_11 = gear_ratio**2 * drivetrain_impedance
off_diag = np.sqrt(3.0/2.0) * torque_constant * gear_ratio
pto_impedance_12 = (off_diag+0j) * np.ones(wec.omega.shape) 
pto_impedance_21 = pto_impedance_12
pto_impedance_22 = winding_impedance
pto_impedance = np.array([[pto_impedance_11, pto_impedance_12],
                          [pto_impedance_21, pto_impedance_22]])

# create PTO
pto = wot.pto.PILinearPTO(nfreq, kinematics, pto_impedance)

# add PTO force to WEC
wec.f_add = pto.force_on_wec
# Out:
# INFO:wecopttool.core:Changing value of 'f_add'. This might cause some attributes to be reset.

# %% [markdown]
# ### Waves

# %%
# waves
wfreq = 0.3
amplitude = 0.0625
phase = -40
waves = wot.waves.regular_wave(f0, nfreq, wfreq, amplitude, phase)

# %% [markdown]
# ### Objective Function

# %%
# objective function
obj_fun = pto.electric_average_power
nstate_opt = pto.nstate

# %% [markdown]
# ### Solve

# %%
# solve
scale_x_wec = 1.0
scale_x_opt = 0.0001
scale_obj = 1.0

options = {'maxiter': 100, 'ftol': 1e-8}

wec_tdom, wec_fdom, x_wec, x_opt, obj, res = wec.solve(
    waves, obj_fun, nstate_opt, optim_options=options,
    scale_x_wec=scale_x_wec, scale_x_opt=scale_x_opt, scale_obj=scale_obj)

# post-process
pto_tdom, pto_fdom = pto.post_process(wec, x_wec, x_opt)
# Out:
# INFO:wecopttool.core:Solving pseudo-spectral control problem.
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.49e+04, 2.19e+04, 1.12e+29]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.38e+03, 1.90e+05, 7.38e+26]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.15e-01, 4.55e-01, 2.01e+07]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [5.52e-02, 8.60e-01, 4.65e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.27e-02, 1.36e+00, 3.55e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.29e-04, 1.34e+00, 5.61e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.91e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.53e-04, 1.34e+00, 4.89e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.54e-04, 1.33e+00, 4.77e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.59e-04, 1.30e+00, 4.20e+00]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.86e-04, 1.14e+00, 9.11e-01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [5.70e-04, 3.25e-02, 1.35e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.56e-04, 3.20e-01, 1.89e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.84e-04, 3.75e-01, 1.61e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.83e-04, 3.73e-01, 1.63e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.79e-04, 3.62e-01, 1.64e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.61e-04, 3.17e-01, 1.66e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.13e-01, 1.65e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.13e-01, 1.65e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.13e-01, 1.65e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.13e-01, 1.65e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.13e-01, 1.65e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.12e-01, 1.65e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.11e-01, 1.66e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.57e-04, 3.09e-01, 1.66e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.60e-04, 2.98e-01, 1.68e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [3.77e-04, 2.49e-01, 1.79e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.84e-04, 1.33e-02, 2.12e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [9.76e-03, 1.61e+01, 3.21e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.92e-03, 1.09e+01, 9.59e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.18e-04, 7.48e-02, 2.43e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.15e-04, 4.19e-02, 2.38e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.58e-04, 4.73e-03, 2.41e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.16e-04, 8.62e-02, 2.46e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.14e-04, 1.63e-01, 2.52e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.79e-04, 1.49e-01, 2.57e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.76e-04, 1.33e-01, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.80e-04, 1.36e-01, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.36e-01, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.36e-01, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.36e-01, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.36e-01, 2.56e+01]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -25.587248897462363
#             Iterations: 50
#             Function evaluations: 73
#             Gradient evaluations: 50

# %% [markdown]
# ### Solve unstructured

# %%
# PTO
pto_ps = wot.pto.PseudoSpectralLinearPTO(nfreq, kinematics, pto_impedance)

# add PTO force to WEC
wec.f_add = pto_ps.force_on_wec

# objective function
obj_fun = pto_ps.electric_average_power
nstate_opt = pto_ps.nstate

# solve
scale_x_wec = 1.0
scale_x_opt = 0.01
scale_obj = 1.0

options = {'maxiter': 100, 'ftol': 1e-8}

_, _, x_wec_ps, x_opt_ps, _, _ = wec.solve(
    waves, obj_fun, nstate_opt, optim_options=options,
    scale_x_wec=scale_x_wec, scale_x_opt=scale_x_opt, scale_obj=scale_obj)
# Out:
# INFO:wecopttool.core:Changing value of 'f_add'. This might cause some attributes to be reset.
# INFO:wecopttool.core:Solving pseudo-spectral control problem.
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.77e-01, 4.60e+01, 4.45e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.48e-01, 5.63e+01, 8.69e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [8.14e-02, 2.75e+01, 1.73e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.34e-02, 2.19e+01, 1.36e+06]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.39e-02, 1.72e+01, 3.34e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.86e-01, 5.56e+00, 7.86e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.34e-02, 5.12e+00, 4.03e+05]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [4.67e-03, 1.01e+00, 4.24e+04]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [9.10e-03, 1.92e+00, 1.23e+04]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.02e-03, 2.85e-01, 6.99e+02]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.27e-04, 1.25e-01, 2.46e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [9.42e-04, 5.42e-02, 1.21e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [1.34e-03, 6.59e-02, 2.28e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.91e-04, 1.21e-02, 2.15e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [2.47e-04, 1.09e-02, 1.91e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [7.71e-04, 2.43e-02, 2.53e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.42e-04, 2.13e-02, 2.52e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.23e-04, 1.68e-02, 2.54e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.77e-04, 2.15e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.81e-04, 2.03e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.80e-04, 2.00e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.77e-04, 2.02e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.79e-04, 2.00e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.98e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.98e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.98e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.98e-02, 2.56e+01]
# INFO:wecopttool.core:[mean(x_wec), mean(x_opt), obj_fun(x)]: [6.78e-04, 1.98e-02, 2.56e+01]
# INFO:wecopttool.core:Optimization terminated successfully    (Exit mode 0)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -25.587248887620202
#             Iterations: 28
#             Function evaluations: 40
#             Gradient evaluations: 28

# %% [markdown]
# ### CC (Electrical) Solution

# %%
Z_11 = pto_impedance[0, 0, :]
Z_12 = pto_impedance[0, 1, :]
Z_21 = pto_impedance[1, 0, :]
Z_22 = pto_impedance[1, 1, :]

idof = 0
Fe = wec_fdom['excitation_force'][1:, idof]
Zi = wec.hydro.Zi[:, idof, idof]

V_th = Z_21 / (Z_11 - Zi) * Fe
Z_th = Z_22 - (Z_12*Z_21) / (Z_11 - Zi)

cc_current_fd = V_th / (2*Z_th.real)
cc_voltage_fd = -1.0 * Z_th.conj() * cc_current_fd

cc_current_td = wot.post_process_continuous_time(cc_current_fd)
cc_voltage_td = wot.post_process_continuous_time(cc_voltage_fd)

# %%
# Mechanical quantities
cc_velocity_fd = np.zeros(nfreq) *0j
cc_force_fd = np.zeros(nfreq) * 0j

for ifreq in range(nfreq):
    abcd_inv = np.linalg.inv(pto._impedance_abcd[:, :, ifreq])
    vec_elec = np.array([[cc_current_fd[ifreq]], [cc_voltage_fd[ifreq]]])
    vec_mech = abcd_inv @ vec_elec
    cc_velocity_fd[ifreq] = vec_mech[0, 0]
    cc_force_fd[ifreq] = vec_mech[1, 0]

cc_velocity_fd = xr.DataArray(
    cc_velocity_fd, dims=["omega"], coords=[("omega", wec.omega),],)
cc_force_fd = xr.DataArray(
    cc_force_fd, dims=["omega"], coords=[("omega", wec.omega), ],)

cc_velocity_td = wot.post_process_continuous_time(cc_velocity_fd)
cc_force_td = wot.post_process_continuous_time(cc_force_fd)

# %% [markdown]
# ### Compare Results to CC

# %%
nsubsteps = 10
t = wec.make_time_vec(nsubsteps)

# plot electrical power
plt.figure()
plt.plot(t, cc_current_td(t), '-', label='Optimal')
plt.plot(t, pto.electric_current(
    wec, x_wec, x_opt, nsubsteps), '--', label='PI Controller')
plt.xlabel('time [s]')
plt.ylabel('current [A]')
plt.legend()

plt.figure()
plt.plot(t, cc_voltage_td(t), '-')
plt.plot(t, pto.electric_voltage(wec, x_wec, x_opt, nsubsteps), '--')
plt.xlabel('time [s]')
plt.ylabel('voltage [V]')

plt.figure()
plt.plot(t, cc_current_td(t)*cc_voltage_td(t), '-', linewidth=2, color="0.5", label='Optimal')
plt.plot(t, pto_ps.electric_power(wec, x_wec_ps, x_opt_ps, nsubsteps), '-', label='Unstructured')
plt.plot(t, pto.electric_power(wec, x_wec, x_opt, nsubsteps), '--', label='PI')
plt.xlabel('time [s]')
plt.ylabel('electrical power [W]')
plt.legend()
plt.savefig('verification_epower.pdf')

# %%
# plot mechanical power
plt.figure()
plt.plot(t, cc_velocity_td(t), '-', label='Optimal')
plt.plot(t, pto.velocity(
    wec, x_wec, x_opt, nsubsteps), '--', label='PI')
plt.xlabel('time [s]')
plt.ylabel('velocity [m/s]')
plt.legend()

plt.figure()
plt.plot(t, cc_force_td(t), '-')
plt.plot(t, pto.force(wec, x_wec, x_opt, nsubsteps), '--')
plt.xlabel('time [s]')
plt.ylabel('force [N]')

plt.figure()
plt.plot(t, cc_velocity_td(t)*cc_force_td(t), '-')
plt.plot(t, pto.power(wec, x_wec, x_opt, nsubsteps), '--')
plt.xlabel('time [s]')
plt.ylabel('mechanical power [W]')
# Out:
# Text(0, 0.5, 'mechanical power [W]')

# %% [markdown]
# ### PI Optimal Gains

# %%
ind = int(np.where(np.isclose(wec.freq, wfreq))[0])
tmp = cc_force_fd / cc_velocity_fd
tmp = tmp.values[ind]
(-np.imag(tmp)*wec.omega[ind], np.real(tmp))
# Out:
# (7318.135330821697, -4605.65764773741)

# %%
x_opt
# Out:
# array([ 7318.13533622, -4605.65765161])
