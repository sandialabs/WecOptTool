# %% [markdown]
# # Tutorial 3 - LUPA
#
# The main goal of this tutorial is to demonstrate how to set up a WEC design problem with a more complex and realistic setup. We use the [Lab Upgrade Point Absorber (LUPA)](https://pmec-osu.github.io/LUPA/) device, an open source two-body heaving point absorber under development by Oregon State University. A deep dive video demonstration of the LUPA device and its features can be viewed [here](https://www.youtube.com/watch?v=gCcAu7H9lQI). We will numerically replicate LUPA testing in the Large Wave Flume at the [O.H. Hinsdale Wave Research Laboratory](https://engineering.oregonstate.edu/wave-lab) in order to provide further design optimization for the WEC device concept. This tutorial builds on the previous ones and introduces:
# - a WEC comprised of multiple bodies
# - setting up a WEC with multiple degrees of freedom (DOF) using generalized modes
# - more complex PTO kinematics that depend on more than one WEC DOF
# - realistic constraints including generator maximum and continuous torque, and maximum rotational speed
# - irregular waves
# - mooring system dynamics
#
# A secondary goal is for this notebook to serve as a tool for those who are planning to run experiments with the LUPA device, to inform their experiment design.
#
# As with previous tutorials, this tutorial consists of two parts, with the second section building upon the first.
#
# 1. [Optimal control of a two-body WEC](#1.-Optimal-control-of-a-two-body-WEC)
# 2. [Control co-design of the PTO sprocket sizing for maximum electrical power](#2.-Control-co-design-of-the-PTO-sprocket-sizing-for-maximum-electrical-power)
#
# <p><img src="rendering.png" alt="Digital rendering of the LUPA" width="310"> <img src="flume.jpg" alt="Picture of the LUPA floating in the flume in calm water. Both bodies and mooring are visible." width="500"> <img src="flume_dry.jpg" alt="Picture of the LUPA in the dry flume. Both bodies and mooring are visible. A ladder and person next to it gives context of the scale." width="500"></p>

# %%
import gmsh, pygmsh
import capytaine as cpy
import autograd.numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from scipy.optimize import brute
from copy import deepcopy

import wecopttool as wot

## debug
wot.set_loglevel("INFO")

## set colorblind-friendly colormap for plots
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=['#E69F00', '#56B4E9', '#009E73', '#F0E442', '#0072B2', '#D55E00', '#CC79A7'])

# %% [markdown]
# ## 1. Optimal control of a two-body WEC
#
# #### WEC object
# The creation of the `WEC` object is fundamentally identical to previous tutorials, where we use meshes of the WEC to create Capytaine `FloatingBody` objects, run BEM using Capytaine, and use the `WEC.from_bem()` method to create the `WEC` object. The key here is that the LUPA is a two-body device (consisting of a float and a spar), which move independently in heave but in unison for all other degrees of freedom. To model this in WecOptTool, we can create a `FloatingBody` object for each body separately with a heave DOF, combine them into a single object afterwards, and be sure the combined mass and inertia properties are properly set.
#
# We will analyze the device in its four planar degrees of freedom: the heave of the buoy, heave of the spar, combined device surge, and combined device pitch, for a total of 4 degrees of freedom. Here we are using the generalized modes approach. Alternatively we could include all 3 planar DOF for each body separately and add two constraints for the pitch and surge to be equal for both bodies.
#
# #### Geometry
# The mass properties of the LUPA have been provided from measurements of the physical device by Oregon State University, as follows:

# %%
# provided by OSU
float_mass_properties = {
    'mass': 248.721,
    'CG': [0.01, 0, 0.06],
    'MOI': [66.1686, 65.3344, 17.16],
}

spar_mass_properties = {
    'mass': 175.536,
    'CG': [0, 0, -1.3],
    'MOI': [253.6344, 250.4558, 12.746],
}

# %% [markdown]
# #### Mesh creation of the float
#
# Here we create the mesh based on the dimensions provided by Oregon State University using *pygmsh* as in the other tutorials.

# %%
# mesh
mesh_size_factor = 0.3
r1 = 1.0/2  # top radius
r2 = 0.4/2  # bottom radius
h1 = 0.5  
h2 = 0.21
freeboard = 0.3
r3 = 0.10/2 + 0.05  # hole radius  # TODO

with pygmsh.occ.Geometry() as geom:
    gmsh.option.setNumber('Mesh.MeshSizeFactor', mesh_size_factor)
    cyl = geom.add_cylinder([0, 0, 0], [0, 0, -h1], r1)
    cone = geom.add_cone([0, 0, -h1], [0, 0, -h2], r1, r2)
    geom.translate(cyl, [0, 0, freeboard])
    geom.translate(cone, [0, 0, freeboard])
    tmp = geom.boolean_union([cyl, cone])
    bar = geom.add_cylinder([0, 0, 10], [0,0,-20], r3)
    geom.boolean_difference(tmp, bar)
    mesh_float = geom.generate_mesh()

# %% [markdown]
# Again, we will only add the heave DOF for now. The surge and pitch will be added after we combine the two `FloatingBody` objects.

# %%
# floating body
float_fb = cpy.FloatingBody.from_meshio(mesh_float, name='float')
float_fb.add_translation_dof(name='Heave')

# %% [markdown]
# We can now visualize the mesh.

# %%
# show
float_fb.show_matplotlib()

# float_fb.show()  # interactive, close pop-up image before being able to continue running the notebook

# %% [markdown]
# #### Mesh creation of the spar
#
# We now create the spar mesh in the same way as for the float, with the dimensions given by Oregon State University.
#
# <p><img src="spar.png" alt="spar dimensions schematic from OSU" width=700></p>

# %%
# mesh
mesh_size_factor = 0.1
r1 = 0.45/2  # body
r2 = 0.45  # plate
r3 = 0.10/2  # bar
h1 = 1.20  
h2 = 0.01
h3a = 3.684 - 2.05
submergence = 2.05 - h1 - h2

with pygmsh.occ.Geometry() as geom:
    gmsh.option.setNumber('Mesh.MeshSizeFactor', mesh_size_factor)
    body = geom.add_cylinder([0, 0, 0], [0, 0, -h1], r1)
    geom.translate(body, [0, 0, -submergence])
    plate = geom.add_cylinder([0, 0, 0], [0, 0, -h2], r2)
    geom.translate(plate, [0, 0, -(submergence+h1)])
    bar = geom.add_cylinder([0, 0, h3a], [0, 0, -(h3a+submergence)], r3)
    geom.boolean_union([bar, body, plate])
    mesh_spar = geom.generate_mesh()

# %%
# floating body
spar_fb = cpy.FloatingBody.from_meshio(mesh_spar, name='spar')
spar_fb.add_translation_dof(name='Heave')

# %%
# show
fig = plt.figure()
xmin, xmax, ymin, ymax, zmin, zmax = spar_fb.mesh.axis_aligned_bbox
scalez = (zmax-zmin) / (xmax-xmin)
ax = fig.add_subplot(111, projection='3d')
ax.set_box_aspect(aspect=(1,1,scalez))
spar_fb.show_matplotlib(ax=ax)
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)

# spar_fb.show()  # interactive, close pop-up image before being able to continue running the notebook

# %% [markdown]
# #### Combined `FloatingBody`
#
# With both WEC bodies defined separately, we can now create a union of the bodies and define the properties for the overall LUPA device. At the equilibrium position the float is neutrally buoyant while the spar is positively buoyant and requires mooring pre-tension. The combined center of mass and moment of inertia can be found by using the given values weighted by the mass (via the parallel axis theorem for the moment of inertia). This is also when we can specify the surge and pitch degrees of freedom.
#
# We are using the density of *fresh* water, $\rho = 1000 kg/m^3$, since we are modeling LUPA in a wave flume.

# %%
# density of fresh water
rho = 1000

# floating body
lupa_fb = float_fb + spar_fb
lupa_fb.name = 'LUPA'

# mass properties float
mass_float = float_mass_properties['mass'] 
cm_float = np.array(float_mass_properties['CG'])
pitch_inertia_float = float_mass_properties['MOI'][1] 

# mass properties spar
mass_spar = spar_mass_properties['mass']  
cm_spar = np.array(spar_mass_properties['CG'])
pitch_inertia_spar = spar_mass_properties['MOI'][1] 

 # mass properties LUPA
lupa_fb.center_of_mass = (mass_float*cm_float + mass_spar*cm_spar) / (mass_float + mass_spar)
lupa_fb.rotation_center = lupa_fb.center_of_mass

# pitch moment of inertia of LUPA using the parallel axis theorem 
d_float = cm_float[2] - lupa_fb.center_of_mass[2]
d_spar = cm_spar[2] - lupa_fb.center_of_mass[2]
pitch_inertia = (
    pitch_inertia_float + mass_float*d_float**2 + 
    pitch_inertia_spar + mass_spar*d_spar**2
)
inertia = np.diag([mass_float, mass_spar, lupa_fb.disp_mass(), pitch_inertia])

# additional DOFs
lupa_fb.add_translation_dof(name='Surge')
lupa_fb.add_rotation_dof(name='Pitch')

# %% [markdown]
# We can now visualize the combined mesh.

# %%
# show
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
xmin, xmax, ymin, ymax, zmin, zmax = lupa_fb.mesh.axis_aligned_bbox
scalez = (zmax-zmin) / (xmax-xmin)
ax = fig.add_subplot(111, projection='3d')
ax.set_box_aspect(aspect=(1,1,scalez))
lupa_fb.show_matplotlib(ax=ax)
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)

# lupa_fb.show()

# %% [markdown]
# #### BEM
# With the LUPA geometry and physical properties fully defined, we can now run Capytaine to calculate the hydrodynamic and hydrostatic coefficients of the device, as done in previous tutorials. Capytaine can handle generalized modes and will calculate the coefficients for our 4 degrees of freedom. Because we are now using irregular waves, we need significantly more frequencies to capture the entire wave spectrum. The BEM coefficients have been pre-calculated and are saved in a file. To re-run the BEM, which takes about 1 hour, simply delete the existing file `./data/bem.nc`.

# %%
# compute hydrodynamic coefficients
f1 = 0.02
nfreq = 100
freq = wot.frequency(f1, nfreq, False)

# read BEM data file if it exists
filename = './data/bem.nc'
try:
    bem_data = wot.read_netcdf(filename)
except:
    bem_data = wot.run_bem(lupa_fb, freq)
    wot.write_netcdf(filename, bem_data)

# hydrostatics
_ = lupa_fb.compute_hydrostatics(rho=rho)
hydrostatic_stiffness = lupa_fb.hydrostatic_stiffness
# Out:
# INFO:capytaine.bodies.bodies:Clipping LUPA_immersed with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=0.126, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.126, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.126, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.126, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.126, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=0.251, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.251, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.251, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.251, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.251, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=0.377, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.377, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.377, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.377, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.377, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=0.503, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.503, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.503, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.503, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.503, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=0.628, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.628, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.628, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.628, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.628, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=0.754, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.754, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.754, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.754, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.754, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=0.880, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.880, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.880, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.880, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=0.880, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.005, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.005, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.005, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.005, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.005, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.131, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.131, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.131, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.131, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.131, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.257, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.257, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.257, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.257, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.257, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.382, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.382, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.382, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.382, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.382, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.508, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.508, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.508, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.508, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.508, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.634, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.634, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.634, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.634, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.634, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.759, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.759, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.759, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.759, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.759, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=1.885, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.885, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.885, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.885, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=1.885, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.011, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.011, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.011, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.011, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.011, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.136, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.136, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.136, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.136, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.136, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.262, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.262, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.262, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.262, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.262, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.388, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.388, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.388, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.388, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.388, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.513, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.513, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.513, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.513, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.513, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.639, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.639, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.639, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.639, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.639, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.765, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.765, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.765, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.765, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.765, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=2.890, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.890, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.890, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.890, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=2.890, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.016, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.016, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.016, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.016, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.016, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.142, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.142, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.142, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.142, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.142, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.267, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.267, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.267, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.267, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.267, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.393, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.393, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.393, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.393, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.393, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.519, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.519, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.519, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.519, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.519, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.644, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.644, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.644, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.644, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.644, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.770, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.770, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.770, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.770, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.770, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=3.896, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.896, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.896, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.896, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=3.896, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.021, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.021, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.021, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.021, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.021, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.147, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.147, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.147, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.147, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.147, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.273, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.273, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.273, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.273, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.273, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.398, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.398, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.398, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.398, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.398, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.524, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.524, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.524, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.524, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.524, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.650, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.650, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.650, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.650, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.650, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.775, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.775, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.775, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.775, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.775, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=4.901, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.901, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.901, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.901, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=4.901, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.027, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.027, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.027, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.027, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.027, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.152, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.152, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.152, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.152, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.152, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.278, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.278, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.278, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.278, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.278, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.404, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.404, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.404, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.404, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.404, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.529, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.529, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.529, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.529, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.529, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.655, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.655, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.655, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.655, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.655, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.781, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.781, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.781, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.781, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.781, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=5.906, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.906, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.906, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.906, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=5.906, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.032, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.032, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.032, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.032, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.032, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.158, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.158, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.158, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.158, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.158, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.283, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.283, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.283, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.283, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.283, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.409, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.409, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.409, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.409, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.409, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.535, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.535, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.535, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.535, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.535, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.660, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.660, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.660, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.660, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.660, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.786, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.786, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.786, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.786, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.786, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=6.912, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.912, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.912, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.912, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=6.912, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.037, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.037, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.037, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.037, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.037, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.163, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.163, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.163, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.163, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.163, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.288, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.288, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.288, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.288, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.288, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.414, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.414, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.414, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.414, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.414, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.540, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.540, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.540, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.540, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.540, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.665, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.665, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.665, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.665, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.665, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.791, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.791, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.791, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.791, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.791, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=7.917, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.917, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.917, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.917, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=7.917, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.042, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.042, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.042, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.042, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.042, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.168, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.168, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.168, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.168, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.168, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.294, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.294, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.294, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.294, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.294, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.419, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.419, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.419, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.419, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.419, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.545, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.545, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.545, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.545, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.545, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.671, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.671, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.671, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.671, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.671, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.796, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.796, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.796, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.796, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.796, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=8.922, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.922, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.922, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.922, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=8.922, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=9.048, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.048, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.048, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.048, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.048, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=9.173, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.173, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.173, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.173, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.173, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=9.299, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.299, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# ...
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=9.676, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.676, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.676, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.676, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.676, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=9.802, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.802, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.802, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.802, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.802, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=9.927, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.927, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.927, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.927, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=9.927, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.053, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.053, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.053, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.053, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.053, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.179, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.179, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.179, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.179, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.179, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.304, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.304, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.304, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.304, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.304, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.430, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.430, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.430, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.430, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.430, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.556, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.556, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.556, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.556, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.556, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.681, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.681, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.681, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.681, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.681, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.807, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.807, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.807, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.807, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.807, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=10.933, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.933, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.933, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.933, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=10.933, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.058, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.058, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.058, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.058, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.058, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.184, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.184, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.184, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.184, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.184, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.310, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.310, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.310, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.310, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.310, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.435, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.435, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.435, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.435, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.435, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.561, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.561, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.561, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.561, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.561, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.687, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.687, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.687, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.687, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.687, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.812, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.812, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.812, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.812, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.812, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=11.938, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.938, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.938, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.938, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=11.938, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=12.064, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.064, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.064, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.064, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.064, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=12.189, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.189, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.189, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.189, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.189, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=12.315, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.315, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.315, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.315, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.315, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=12.441, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.441, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.441, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.441, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.441, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bem.solver:Solve DiffractionProblem(body=LUPA_immersed, omega=12.566, depth=inf, wave_direction=0.000, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.566, depth=inf, radiating_dof=float__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.566, depth=inf, radiating_dof=spar__Heave, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.566, depth=inf, radiating_dof=Surge, rho=1025.0).
# INFO:capytaine.bem.solver:Solve RadiationProblem(body=LUPA_immersed, omega=12.566, depth=inf, radiating_dof=Pitch, rho=1025.0).
# INFO:capytaine.bodies.bodies:Clipping LUPA with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# WARNING:capytaine.bodies.bodies:Non-rigid dofs: {'float__Heave', 'spar__Heave'} are detected and respective inertia coefficients are assigned as NaN.

# %% [markdown]
# We now visualize the BEM results.

# %%
# plot coefficients
radiating_dofs = bem_data.radiating_dof.values
influenced_dofs = bem_data.influenced_dof.values

# plots
fig_am, ax_am = plt.subplots(len(radiating_dofs), len(influenced_dofs), tight_layout=True, sharex=True)
fig_rd, ax_rd = plt.subplots(len(radiating_dofs), len(influenced_dofs), tight_layout=True, sharex=True)
fig_ex, ax_ex = plt.subplots(len(influenced_dofs), 1, tight_layout=True, sharex=True, figsize=(8,8))

# plot titles
fig_am.suptitle('Added Mass Coefficients', fontweight='bold')
fig_rd.suptitle('Radiation Damping Coefficients', fontweight='bold')
fig_ex.suptitle('Wave Excitation Coefficients', fontweight='bold')

# subplotting across 4DOF
sp_idx = 0
for i, rdof in enumerate(radiating_dofs):
    for j, idof in enumerate(influenced_dofs):
        sp_idx += 1
        if i == 0:
            np.abs(bem_data.diffraction_force.sel(influenced_dof=idof)).plot(ax=ax_ex[j], linestyle='dashed', label='Diffraction force')
            np.abs(bem_data.Froude_Krylov_force.sel(influenced_dof=idof)).plot(ax=ax_ex[j], linestyle='dashdot', label='Froude-Krylov force')
            ex_handles, ex_labels = ax_ex[j].get_legend_handles_labels()
            ax_ex[j].set_title(f'{idof}', fontsize=8.5)
            ax_ex[j].set_xlabel('')
            ax_ex[j].set_ylabel('')
        if j <= i:
            bem_data.added_mass.sel(radiating_dof=rdof, influenced_dof=idof).plot(ax=ax_am[i, j])
            bem_data.radiation_damping.sel(radiating_dof=rdof, influenced_dof=idof).plot(ax=ax_rd[i, j])
            if i == len(radiating_dofs)-1:
                ax_am[i, j].set_xlabel(f'$\omega$\n{idof}', fontsize=10)
                ax_rd[i, j].set_xlabel(f'$\omega$\n{idof}', fontsize=10)
                ax_ex[j].set_xlabel(f'$\omega$', fontsize=10)
            else:
                ax_am[i, j].set_xlabel('')
                ax_rd[i, j].set_xlabel('')
            if j == 0:
                ax_am[i, j].set_ylabel(f'{rdof}', fontsize=10)
                ax_rd[i, j].set_ylabel(f'{rdof}', fontsize=10)
            else:
                ax_am[i, j].set_ylabel('')
                ax_rd[i, j].set_ylabel('')
            ax_am[i, j].set_title('')
            ax_rd[i, j].set_title('')
        else:
            fig_am.delaxes(ax_am[i, j])
            fig_rd.delaxes(ax_rd[i, j])
fig_ex.legend(ex_handles, ex_labels, loc=(0.22, 0.0), ncol=2)

# %% [markdown]
# #### PTO system
#
# The PTO model is similar to the one developed in Tutorial 2 but using the values corresponding to the LUPA PTO.
# The main difference is that in the LUPA the gear ratio can be modified by changing the interchangeable sprocket for one with a different radius.
# The motivation here is that operation in different wave conditions or different control schemes might have different torque and speed requirements.
# Oregon State University has three sprockets of diameters 81.5mm (8MX-32S-36), 127.3mm (8MX-50S-36), 203.7mm (8MX-80S-36), but the manufacturer provides a fine selection of radius size in this range.
#
# The PTO system consists of a [generator](https://akribis-systems.s3-us-west-2.amazonaws.com/pdfs/catalogs/adr-b.pdf), the [interchangeable sprocket](https://assets.gates.com/content/dam/gates/home/knowledge-center/resource-library/catalogs/old-pc_carbon_manual17595_2011.pdf), and two [idler pulleys](https://dpk3n3gg92jwt.cloudfront.net/domains/gates.pt/pdf/77234200.pdf) driven by a belt.
#
# <p><img src="pto.png" alt="Schematic of the PTO system showing dimensions and parts." width=740> <img src="pto_rendering.png" alt="Digital rendering of the LUPA with PTO mechanism visible." width=458></p>
#
# We start by defining all the manufacturer-specified components.

# %%
conv_d = 0.0254  # in -> m
conv_m = 0.453592  # lb -> kg
conv_moi = 0.453592 * 0.3048**2  # lb*ft^2 -> kg*m^2
conv_s = 2*np.pi  # rpm -> rad/s

# sprocket
sprockets = {
    '8MX-32S-36': {
        'diameter': 3.208 * conv_d,
        'mass': 1.7 * conv_m,
        'MOI': 0.02 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-33S-36': {
        'diameter': 3.308 * conv_d,
        'mass':  3.31* conv_m,
        'MOI': 0.022 * conv_moi,
        'design': 'AF',
    },
    '8MX-34S-36': {
        'diameter': 3.409 * conv_d,
        'mass': 1.8 * conv_m,
        'MOI': 0.026 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-35S-36': {
        'diameter': 3.509 * conv_d,
        'mass': 3.51 * conv_m,
        'MOI': 0.029 * conv_moi,
        'design': 'AF',
    },
    '8MX-36S-36': {
        'diameter': 3.609 * conv_d,
        'mass': 2.1 * conv_m,
        'MOI': 0.032 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-37S-36': {
        'diameter': 3.709 * conv_d,
        'mass': 3.78 * conv_m,
        'MOI': 0.039 * conv_moi,
        'design': 'AF',
    },
    '8MX-38S-36': {
        'diameter': 3.810 * conv_d,
        'mass': 2.4 * conv_m,
        'MOI': 0.04 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-39S-36': {
        'diameter': 3.910 * conv_d,
        'mass': 3.91 * conv_m,
        'MOI': 0.048 * conv_moi,
        'design': 'AF',
    },
    '8MX-40S-36': {
        'diameter': 4.010 * conv_d,
        'mass': 2.5 * conv_m,
        'MOI': 0.049 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-41S-36': {
        'diameter': 4.110 * conv_d,
        'mass': 4.11 * conv_m,
        'MOI': 0.057 * conv_moi,
        'design': 'AF',
    },
    '8MX-42S-36': {
        'diameter': 4.211 * conv_d,
        'mass': 2.8 * conv_m,
        'MOI': 0.061 * conv_moi,
        'design': 'AF-1',  
    },
    '8MX-45S-36': {
        'diameter': 4.511 * conv_d,
        'mass': 3.8 * conv_m,
        'MOI': 0.09 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-48S-36': {
        'diameter': 4.812 * conv_d,
        'mass': 4.3 * conv_m,
        'MOI': 0.114 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-50S-36': {
        'diameter': 5.013 * conv_d,
        'mass': 5.1 * conv_m,
        'MOI': 0.143 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-53S-36': {
        'diameter': 5.314 * conv_d,
        'mass': 5.5 * conv_m,
        'MOI': 0.169 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-56S-36': {
        'diameter': 5.614 * conv_d,
        'mass': 6.5 * conv_m,
        'MOI': 0.221 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-60S-36': {
        'diameter': 6.015 * conv_d,
        'mass': 8.9 * conv_m,
        'MOI': 0.352 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-63S-36': {
        'diameter': 6.316 * conv_d,
        'mass': 10.4 * conv_m,
        'MOI': 0.556 * conv_moi,
        'design': 'AF-1',
    },
    '8MX-67S-36': {
        'diameter': 6.717 * conv_d,
        'mass': 6.5 * conv_m,
        'MOI': 0.307 * conv_moi,
        'design': 'DF-1',
    },
    '8MX-71S-36': {
        'diameter': 7.118 * conv_d,
        'mass': 7.0 * conv_m,
        'MOI': 0.365 * conv_moi,
        'design': 'DF-1',
    },
    '8MX-75S-36': {
        'diameter': 7.519 * conv_d,
        'mass': 7.3 * conv_m,
        'MOI': 0.423 * conv_moi, 
        'design': 'DF-1',
    },
    '8MX-80S-36': {
        'diameter': 8.020 * conv_d,
        'mass': 17.9 * conv_m,
        'MOI': 1.202 * conv_moi,  
        'design': 'BF-1',
    },
}

# idler pulleys
idler_pulley = {
    'model': 'Gates 4.25X2.00-IDL-FLAT',
    'diameter': 4.25 * conv_d, 
    'face_width': 2.00 * conv_d,
    'mass': 7.6 * conv_m,
    'max_rpm': 5840,
    'MOI': None,  # Not specified
}

# generator. Note: Model ADR220-B175 data not listed online, but we have spec sheet available on request 
generator = {
    'torque_constant': 8.51,  # N*m/A
    'winding_resistance': 5.87,  # Ω 
    'winding_inductance' : 0.0536,  # H 
    'max_torque': 137.9,  # N*m
    'continuous_torque': 46,  # N*m
    'max_speed': 150 * conv_s,  # rad/s
    'MOI': 1.786e-2,  # kg*m^2 
}

# %% [markdown]
# We then define the PTO based on these part specifications.
# For Part 1, where we are setting up the problem, we will use the mid-size sprocket of diameter 127.3mm (8MX-50S-36).

# %%
# drivetrain 
def gear_ratio(pulley_radius):
    return 1/pulley_radius  # rad/m 

drivetrain_friction = 0.5  # N*m*s/rad  # this will be estimated experimentally in the future
drivetrain_stiffness = 0  # N*m/rad 
idler_pulley['MOI'] = 0.5 * idler_pulley['mass'] * (idler_pulley['diameter']/2)**2  # kg*m^2, estimate based on mass and disk assumption

# impedance model
def pto_impedance(sprocket_model, omega=bem_data.omega.values):
    pulley_ratio = sprockets[sprocket_model]['diameter'] / idler_pulley['diameter']
    drivetrain_inertia = (
        generator['MOI'] + 
        sprockets[sprocket_model]['MOI'] + 
        2 * idler_pulley['MOI']*pulley_ratio**2
    )  # N*m^2
    drivetrain_impedance = (
        1j*omega*drivetrain_inertia + 
        drivetrain_friction + 
        1/(1j*omega)*drivetrain_stiffness
    ) 
    winding_impedance = generator['winding_resistance'] + 1j*omega*generator['winding_inductance']
    pulley_radius = sprockets[sprocket_model]['diameter'] / 2
    pto_impedance_11 = -1* gear_ratio(pulley_radius)**2 * drivetrain_impedance
    off_diag = -1*np.ones(omega.shape) * (
        np.sqrt(3.0/2.0) * generator['torque_constant'] * gear_ratio(pulley_radius) + 0j)
    pto_impedance_12 = off_diag 
    pto_impedance_21 = off_diag
    pto_impedance_22 = winding_impedance
    impedance = np.array([[pto_impedance_11, pto_impedance_12],
                          [pto_impedance_21, pto_impedance_22]])
    return impedance

# PTO object
name = ["PTO_Heave",]
kinematics = np.array([[1, -1, 0, 0],])
pto_ndof = 1
controller = None
loss = None
default_sprocket = '8MX-50S-36'
pto = wot.pto.PTO(pto_ndof, kinematics, controller, pto_impedance(default_sprocket), loss, name)

# %% [markdown]
# ### Constraints
# In this tutorial we include realistic constraints on both the device motions and the generator operation.
# - The **maximum stroke** (difference in heave between the float and spar) is 0.5m. Although there are end-stops (hard stop), the controller should ensure a soft stop. So, instead of modeling the hard stop we will add a constraint.
# - The generator has both a **maximum torque** and **maximum speed**. It is important that we do not exceed that during operation.
# - Generators also have a **continuous torque** requirement. The RMS torque during operation should not exceed this value or we risk damage to and failure of the machine. The torque can go higher that this (up to the maximum) for brief periods as long as the RMS torque remains below this threshold.
#
# We enforce all these through constraints on our design optimization problem.

# %%
## Displacements
# maximum stroke
stroke_max = 0.5  # m
def const_stroke_pto(wec, x_wec, x_opt, waves): 
    pos = pto.position(wec, x_wec, x_opt, waves, nsubsteps)
    return stroke_max - np.abs(pos.flatten())

## GENERATOR
# peak torque
default_radius = sprockets[default_sprocket]['diameter'] / 2
def const_peak_torque_pto(wec, x_wec, x_opt, waves, radius=default_radius): 
    """Instantaneous torque must not exceed max torque Tmax - |T| >=0 
    """
    torque = pto.force(wec, x_wec, x_opt, waves, nsubsteps) / gear_ratio(radius)
    return generator['max_torque'] - np.abs(torque.flatten())

# continuous torque
def const_torque_pto(wec, x_wec, x_opt, waves, radius=default_radius): 
    """RMS torque must not exceed max continous torque 
        Tmax_conti - Trms >=0 """
    torque = pto.force(wec, x_wec, x_opt, waves, nsubsteps) / gear_ratio(radius)
    torque_rms = np.sqrt(np.mean(torque.flatten()**2))
    return generator['continuous_torque'] - torque_rms

# max speed
def const_speed_pto(wec, x_wec, x_opt, waves, radius=default_radius): 
    rot_vel = pto.velocity(wec, x_wec, x_opt, waves, nsubsteps) * gear_ratio(radius)
    return generator['max_speed'] - np.abs(rot_vel.flatten())

## Constraints
constraints = [
    {'type': 'ineq', 'fun': const_stroke_pto},
    {'type': 'ineq', 'fun': const_peak_torque_pto},
    {'type': 'ineq', 'fun': const_torque_pto},
    {'type': 'ineq', 'fun': const_speed_pto},
]
# constraints = None  # TODO: DELETE
nsubsteps = 5

# %% [markdown]
# ### Mooring system
# To fully capture the dynamics acting on LUPA in the Large Wave Flume, we must model the mooring system being used to account for the restoring forces acting on the WEC. The LUPA setup uses a 4-line taut mooring system with springs connecting the spar to the wall of the wave flume. The following mooring system properties have been provided by Oregon State University. The initial fairlead coordinates and anchor coordinates are relative to the center of gravity of the combined device:

# %%
pretension = 285 # N
init_fair_coords = np.array([[-0.19, -0.19, -0.228],
                             [-0.19,  0.19, -0.228],
                             [ 0.19, -0.19, -0.228],
                             [ 0.19,  0.19, -0.228]]) # m
anch_coords = np.array([[-1.95, -1.6, -0.368],
                        [-1.95,  1.6, -0.368],
                        [ 1.95, -1.6, -0.368],
                        [ 1.95,  1.6, -0.368]]) # m
line_ax_stiff = 963. # N/m

# %% [markdown]
# There are several analytical and numerical methods commonly used to model mooring system kinematics for offshore systems, ranging from static analysis to determine equilibrium forces, all the way to FEA used to calculate the fully dynamic response of the mooring system components. For this design problem, we're mostly concerned with modeling the correct response of LUPA due to operational waves, so the high-fidelity methods are unnecessary at this design stage. While a purely linearized approach is common here, the symmetry of the taut lines in this current system allows us to instead use an analytical solution derived by Al-Solihat and Nahon (https://doi.org/10.1080/17445302.2015.1089052), which allows us to capture nonlinear mooring effects and off-diagonal terms in the mooring stiffness matrix without any significant increase in computation time.
#
# This solution takes an exact analysis of the derivatives of the classic elastic catenary equations and simplifies them by assuming the taut lines have no sag and negligible mass, allowing for the differential changes of the horizontal and vertical restoring force to be calculated as
# $$ \frac{\partial F_{hor}}{\partial l} = K_{axial}\textup{cos}^2 \theta + \frac{T}{L} \textup{sin}^2 \theta $$
# $$ \frac{\partial F_{vert}}{\partial h} = K_{axial}\textup{sin}^2 \theta + \frac{T}{L} \textup{cos}^2 \theta $$
# $$ \frac{\partial F_{hor}}{\partial h} = \frac{\partial F_{vert}}{\partial l} = \textup{cos} \theta \textup{sin} \theta \left [ K_{axial}- \frac{T}{L}\right ]$$
#
# where $l$ and $h$ are the horizontal and vertical distance between the anchor points and fairlead points, respectively; $T$ is the pretension; $\theta$ is the angle between the seabed and the mooring line such that $ \theta = \textup{tan}^{-1}(\frac{h}{l}) $; and $L$ is the stretched length of the mooring line such that $L = \sqrt{l^2 + h^2} $
#
# When these equations are applied to the linear stiffness equation in each radiating ($i$) and influencing ($j$) degrees of freedom, $\boldsymbol{K_{mooring}} = - \frac{\partial \boldsymbol{F_{mooring}}}{\partial \boldsymbol{X}} = \sum_{m=1}^{n_{lines}}  [K_{ij}]^{(m)} = - \sum_{m=1}^{n_{lines}}[\frac{\partial (F_{mooring})_i}{\partial X_j}]^{(m)} $, where $X$ are the generalized displacements of the WEC in each degree of freedom, they yield Equation (27) from the reference above which provides an analytical solution to $\boldsymbol{K_{mooring}} $, which translates to the `k_mooring` function below. See the reference above for the full theoretical explanation and derivation of these equations.

# %%
# mooring matrix
def k_mooring(fair_coords, anch_coords, pretension, k_ax, nlines):
    """Calculates the 7DOF effective stiffness matrix of a symmetric taut
    mooring system using an analytical solution.
    """

    theta = np.arctan(
        (fair_coords[2] - anch_coords[2])**2
      / np.sqrt(((fair_coords[0] - anch_coords[0])**2
               + (fair_coords[1] - anch_coords[1])**2)))
    linelen = np.sqrt((fair_coords[0] - anch_coords[0])**2
                + (fair_coords[1] - anch_coords[1])**2
                + (fair_coords[2] - anch_coords[2])**2)
    fair_r = np.sqrt(fair_coords[0]**2 + fair_coords[1]**2)
    fair_z = -fair_coords[2]
    k_hh = 0.5 * nlines * (
        pretension / linelen * (1 + np.sin(theta)**2)
        + k_ax * np.cos(theta)**2)
    k_rh = nlines * (
        pretension / (2*linelen) * (fair_z * (1 + np.sin(theta)**2)
        + fair_r * np.sin(theta) * np.cos(theta))
        + 0.5 * k_ax * (fair_z * np.cos(theta)**2
        - fair_r * np.sin(theta) * np.cos(theta)))
    k_vv = nlines * (pretension / linelen *
        np.cos(theta)**2 + k_ax * np.sin(theta)**2)
    k_rr = nlines * (
        pretension * (fair_z * np.sin(theta) + 0.5 * fair_r * np.cos(theta))
        + (0.5 * pretension / linelen * ((fair_r * np.cos(theta) + fair_z * np.sin(theta))**2
        + fair_z**2))
        + 0.5 * k_ax * (fair_z * np.cos(theta) - fair_r*np.sin(theta))**2)
    k_tt = nlines * (
        pretension * fair_r / linelen * (fair_r + linelen*np.cos(theta)))
    mat = np.zeros([7, 7])
    mat[1, 1] = k_vv
    mat[2, 2] = k_hh
    mat[3, 3] = k_hh
    mat[4, 4] = k_rr
    mat[5, 5] = k_rr
    mat[6, 6] = k_tt
    mat[2, 5] = -k_rh
    mat[5, 2] = -k_rh
    mat[4, 3] = k_rh
    mat[3, 4] = k_rh

    return mat

# %% [markdown]
# `k_mooring` defines the 7x7 mooring matrix for a two-body point absorber WEC. Since we are only concerned with the planar components here, we can extract the rows/columns for the heaves, surge, and pitch to obtain the 4x4 matrix we need here.

# %%
M = k_mooring(init_fair_coords[0, :], anch_coords[0, :], pretension,
              line_ax_stiff, init_fair_coords.shape[0])
ind_4dof = np.array([0, 1, 2, 5])
M_4dof = M[np.ix_(ind_4dof, ind_4dof)]
print(M_4dof)
# Out:
# [[   0.            0.            0.            0.        ]
#  [   0.          504.79122981    0.            0.        ]
#  [   0.            0.         2178.14277582 -492.70812497]
#  [   0.            0.         -492.70812497  285.08177521]]

# %% [markdown]
# Finally, with some more formatting, we can translate the mooring force into the format expected from WecOptTool by treating the mooring matrix as a transfer function and defining it via the `wecopttool.force_from_rao_transfer_function()` function, which multiplies the position of the WEC by the mooring matrix and return the restoring force.

# %%
# mooring
M = xr.DataArray(M_4dof, coords=[bem_data.coords['influenced_dof'], bem_data.coords['radiating_dof']], dims=['influenced_dof', 'radiating_dof'])
moor = ((M + 0j).expand_dims({"omega": bem_data.omega}))
tmp = moor.isel(omega=0).copy(deep=True)
tmp['omega'] = tmp['omega'] * 0
moor = xr.concat([tmp, moor], dim='omega') 
moor = moor.transpose("radiating_dof", "influenced_dof", "omega")
moor = -1*moor  # RHS of equation: -ma = Σf 
mooring_force = wot.force_from_rao_transfer_function(moor, True)

# %% [markdown]
# #### Pre-tension of spar
#
# The spar is positively buoyant at its equilibrium position and relies on pre-tension from the mooring.
# The mooring matrix above only captures the restoring forces from the mooring lines, not the pretension itself.
# Here we have two choices:
# 1. We can ignore this fact. WecOptTool asssumes equilibrium so the pre-tension force is implied.
# 2. Explicitly model the buoyancy, gravity, and pre-tension forces as done in Tutorial 2.
#
# In Tutorial 2 we had constraints on the mooring/tether line (minimum tension, never slack) and therefore it was important to explicitly model these forces. In this case we do not have such constraints and will simply allow to pre-tension force to be implied. This does not affect the solution.

# %% [markdown]
# ### WEC
#
# We are now ready to create our full WEC object.

# %%
# additional forces
f_add = {
    'PTO': pto.force_on_wec,
    'Mooring': mooring_force
}

friction = np.diag([2.0, 2.0, 2.0, 0])  # small amount of friction to avoid small/negative terms

# WEC
wec = wot.WEC.from_bem(bem_data,
                       inertia_matrix=inertia,
                       hydrostatic_stiffness=hydrostatic_stiffness,
                       constraints=constraints,
                       friction=friction,
                       f_add=f_add,
                       dof_names=bem_data.influenced_dof.values,
)

# %% [markdown]
# ### Waves
# Oregon State University has defined two sets of wave testing conditions for the LUPA: one corresponding to the PacWave South site and a scaling factor of 25, and one for the PacWave North site and a scaling factor of 20.
# For each site/scale they provide four wave conditions to test at the Oregon State Large Wave Flume (LWF): the maximum 90<sup>th</sup> percentile, maximum percent annual energy, maximum occurrence, and minimum 10<sup>th</sup> percentile.
#
# In this tutorial we will use the PacWave South conditions and will design for the maximum occurrence wave.
# The wave conditions are specified in terms of significant wave height and peak period.
# We will assume a JONSWAP spectrum.

# %%
waves = {}

# regular (for testing/setup)
amplitude = 0.1
wavefreq = 0.4  # 0.5
phase = 0
wavedir = 0
waves['regular'] = wot.waves.regular_wave(f1, nfreq, wavefreq, amplitude, phase, wavedir)

# irregular wave cases from OSU
wave_cases = {
    'south_max_90': {'Hs': 0.21, 'Tp': 3.09}, 
    'south_max_annual': {'Hs': 0.13, 'Tp': 2.35},
    'south_max_occurrence': {'Hs': 0.07, 'Tp': 1.90},
    'south_min_10': {'Hs': 0.04, 'Tp': 1.48},  
    'north_max_90': {'Hs': 4.90, 'Tp': 15.46}, 
    'north_max_annual': {'Hs': 3.25, 'Tp': 11.76},
    'north_max_occurrence': {'Hs': 1.75, 'Tp': 9.52},
    'north_min_10': {'Hs': 1.00, 'Tp': 7.39}, 
}

def irregular_wave(hs, tp):
    fp = 1/tp
    spectrum = lambda f: wot.waves.jonswap_spectrum(f, fp, hs, gamma=3.3)
    efth = wot.waves.omnidirectional_spectrum(f1, nfreq, spectrum, "JONSWAP")
    return wot.waves.long_crested_wave(efth)

for case, data in wave_cases.items():
    waves[case] = irregular_wave(data['Hs'], data['Tp'])

# %% [markdown]
# We now plot the wave spectra in order to verify that our frequency array is sufficient to capture our target waves (note the dual y-axis here; PacWave South has much smaller significant wave heights than PacWave North, so the PacWave South lines are scaled to see them in adequate detail).

# %%
fig, ax = plt.subplots()
twinax = ax.twinx()
plt1 = np.abs(waves['south_max_90']).plot(ax=ax, color='C0', linestyle='solid', label='South, 90th percentile')
plt2 = np.abs(waves['south_max_annual']).plot(ax=ax, color='C0', linestyle='dotted', label='South, Max Annual')
plt3 = np.abs(waves['south_max_occurrence']).plot(ax=ax, color='C0', linestyle='dashed', label='South, Max Occurrence')
plt4 = np.abs(waves['south_min_10']).plot(ax=ax, color='C0', linestyle='dashdot', label='South, 10th percentile')
ax.set_ylim([0, np.max(np.abs(waves['north_max_occurrence']))/5])
ax.set_xlim([0, 2*np.pi*f1*nfreq])
ax.tick_params(axis='y', labelcolor='C0')

plt5 = np.abs(waves['north_max_90']).plot(ax=twinax, color='C1', linestyle='solid', label='North, 90th percentile')
plt6 = np.abs(waves['north_max_annual']).plot(ax=twinax, color='C1', linestyle='dotted', label='North, Max Annual')
plt7 = np.abs(waves['north_max_occurrence']).plot(ax=twinax, color='C1', linestyle='dashed', label='North, Max Occurrence')
plt8 = np.abs(waves['north_min_10']).plot(ax=twinax, color='C1', linestyle='dashdot', label='North, 10th percentile')
twinax.set_xlim([0, 2*np.pi*f1*nfreq])
twinax.set_ylim(bottom=0)
twinax.set_ylabel('')
twinax.tick_params(axis='y', labelcolor='C1')
twinax.set_title('')

ax.set_title('PacWave wave spectra', fontweight='bold')
plts = plt1 + plt2 + plt3 + plt4 + plt5 + plt6 + plt7 + plt8
ax.legend(plts, [pl.get_label() for pl in plts], ncols=2, frameon=False)
# Out:
# (0.0, 12.566370614359174)

# %% [markdown]
# ### Solve
# We now solve the inner optimization for optimal control strategy for a fixed design.
# The fixed design we will consider is the one with the 127.3mm diameter sprocket.
# The wave case is the one corresponding to the maximum occurrence at the PacWave South site.
# Note: however that it is good practice to first setup the problem using a regular wave.
# We have done this but skip it here for the sake of brevity. To run the regular wave, change the wave selection in the code below.

# %%
# Objective function
obj_fun = pto.average_power
nstate_opt = wec.ncomponents

# Solve
scale_x_wec = 1
scale_x_opt = 1
scale_obj = 1

results = wec.solve(
    waves['south_max_occurrence'],
    # waves['regular'], 
    obj_fun, 
    nstate_opt, 
    scale_x_wec=scale_x_wec,
    scale_x_opt=scale_x_opt,
    scale_obj=scale_obj,
)

print(f'Optimal average electrical power: {results.fun} W')
# Out:
# INFO:wecopttool.core:Solving pseudo-spectral control problem.
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [9.20e-02, 2.19e+01, 3.37e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [7.79e-02, 2.18e+01, 3.08e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.74e-02, 2.10e+01, 2.28e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.41e-02, 2.05e+01, 2.15e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.83e-02, 2.04e+01, 2.11e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.68e-02, 1.94e+01, 1.89e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [4.05e-02, 1.43e+01, 9.78e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.87e-02, 8.54e+00, 4.16e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.56e-02, 7.47e+00, 3.23e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.44e-02, 7.48e+00, 2.96e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.30e-02, 7.58e+00, 2.86e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.71e-02, 7.79e+00, 2.47e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.69e-02, 7.76e+00, 1.87e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.82e-02, 7.22e+00, 1.03e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.08e-02, 6.35e+00, 3.79e-02]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.47e-02, 5.66e+00, 1.09e-03]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.56e-02, 5.63e+00, -2.60e-02]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.61e-02, 5.74e+00, -6.08e-02]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.75e-02, 5.93e+00, -9.94e-02]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.95e-02, 6.16e+00, -1.32e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [3.11e-02, 6.39e+00, -1.63e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [3.18e-02, 6.75e+00, -2.10e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.96e-02, 7.68e+00, -3.01e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.80e-02, 9.18e+00, -4.44e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.00e-02, 1.08e+01, -5.78e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.90e-02, 1.16e+01, -6.34e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.76e-02, 1.16e+01, -6.45e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.67e-02, 1.15e+01, -6.48e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.49e-02, 1.14e+01, -6.57e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 1.14e+01, -6.77e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.31e-02, 1.19e+01, -7.24e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.68e-02, 1.35e+01, -8.12e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.73e-02, 1.62e+01, -9.22e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [2.18e-02, 1.86e+01, -9.89e-01]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.96e-02, 1.93e+01, -1.01e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.76e-02, 1.92e+01, -1.01e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.58e-02, 1.92e+01, -1.01e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.22e-02, 1.91e+01, -1.02e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.04e-02, 1.93e+01, -1.04e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.05e-02, 2.03e+01, -1.09e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.07e-02, 2.24e+01, -1.16e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.24e-02, 2.48e+01, -1.21e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.11e-02, 2.60e+01, -1.23e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.11e-02, 2.60e+01, -1.24e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.11e-02, 2.60e+01, -1.24e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.11e-02, 2.59e+01, -1.24e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.11e-02, 2.60e+01, -1.25e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.12e-02, 2.64e+01, -1.26e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.12e-02, 2.70e+01, -1.28e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.15e-02, 2.75e+01, -1.28e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.13e-02, 2.77e+01, -1.28e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.13e-02, 2.78e+01, -1.29e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.13e-02, 2.81e+01, -1.29e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 2.86e+01, -1.30e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.15e-02, 2.95e+01, -1.32e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 3.05e+01, -1.35e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.17e-02, 3.08e+01, -1.36e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 3.07e+01, -1.36e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 3.06e+01, -1.36e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 3.05e+01, -1.36e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 3.04e+01, -1.36e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 3.03e+01, -1.36e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.16e-02, 3.02e+01, -1.37e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.17e-02, 3.05e+01, -1.38e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.18e-02, 3.13e+01, -1.39e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.19e-02, 3.21e+01, -1.39e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.19e-02, 3.24e+01, -1.40e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.19e-02, 3.24e+01, -1.40e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.19e-02, 3.24e+01, -1.40e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.19e-02, 3.24e+01, -1.40e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.19e-02, 3.24e+01, -1.40e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.19e-02, 3.24e+01, -1.40e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.20e-02, 3.25e+01, -1.40e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.20e-02, 3.27e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.29e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.30e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.30e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.30e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.29e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.29e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.29e+01, -1.41e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.28e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.27e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.27e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.28e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.28e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.28e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.28e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.28e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.28e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.27e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.21e-02, 3.26e+01, -1.42e+00]
# INFO:wecopttool.core:[max(x_wec), max(x_opt), obj_fun(x)]: [1.22e-02, 3.25e+01, -1.42e+00]

# %%
# Post-process
nsubsteps = 5
wec_fdom, wec_tdom = wec.post_process(results, waves['south_max_occurrence'], nsubsteps)
pto_fdom, pto_tdom = pto.post_process(wec, results, waves['south_max_occurrence'], nsubsteps)

# %% [markdown]
# ### Results
# Looking at the response of the optimal solution, we can see the behavior of the WEC and its relationship to our problem constraints:
#
# * __PTO position__ - The PTO position corresponds to the difference in the heaving motion between the two bodies. The PTO position is clearly nowhere near the 0.5 maximum stroke, so the constraint is not plotted here.
# * __Excitation force and velocity__ - Much like Tutorial 2, we would expect the excitation force and velocity of each body to be in phase when maximizing for mechanical power and in the absence of constraints. Given the constraints on the PTO, this is not the case here, especially with the spar. It is also clear that The velocities (or their rotational equivalents) are also nowhere near the generator maximum speed.
# * __Generator torque__ - This plot shows that both of the torque constraints are active for this wave case, and dominate the solution given the lack of relevance of the other constraints above. The response keeps the generator continuous torque within the threshold except for only brief periods, and the peak torque becomes active at the very end of the analyzed timeframe.
# * __Power__ - As expected, the greatest power absorption aligns with the times of greatest PTO velocity and peak torque magnitude.

# %%
fig_res1, ax_res1 = plt.subplots(nrows=4, sharex=True, figsize=(8, 10))

# PTO position
wec_tdom.pos.sel(influenced_dof='spar__Heave').plot(ax=ax_res1[0], linestyle='dashed', color='C7', label='Spar')
wec_tdom.pos.sel(influenced_dof='float__Heave').plot(ax=ax_res1[0], linestyle='dotted', color='C6', label='Float')
pto_tdom.pos.plot(ax=ax_res1[0], label='PTO', color='black')

ax_res1[0].set_ylabel('Position [m]')
ax_res1[0].set_title('PTO position vs. WEC body position', fontweight='bold')
ax_res1[0].legend(ncols=3, loc='lower center', frameon=False)
ax_res1[0].grid(color='0.75', linestyle='-', linewidth=0.5, axis='x')
ax_res1[0].set_xlabel('')

# Excitation and velocity
twinax = ax_res1[1].twinx()
force_excitation_spar = wec_tdom.force.sel(influenced_dof='spar__Heave', type=['Froude_Krylov', 'diffraction'])
force_excitation_spar = force_excitation_spar.sum('type')
plt1 = force_excitation_spar.plot(ax=ax_res1[1], linestyle='dashed', color='C0', label='Spar exc.')
force_excitation_float = wec_tdom.force.sel(influenced_dof='float__Heave', type=['Froude_Krylov', 'diffraction'])
force_excitation_float = force_excitation_float.sum('type')
plt2 = force_excitation_float.plot(ax=ax_res1[1], linestyle='dotted', color='C0', label='Float exc.')
plt3 = wec_tdom.vel.sel(influenced_dof='spar__Heave').plot(ax=twinax, color='C1', linestyle='dashed', label='Spar velocity')
plt4 = wec_tdom.vel.sel(influenced_dof='float__Heave').plot(ax=twinax, color='C1', linestyle='dotted', label='Float velocity')
twinax.set_ylabel('Velocity [m/s]', color='C1')
twinax.tick_params(axis='y', labelcolor='C1')
twinax.set_title('')
twinax.autoscale(enable=True, axis='x', tight=False)
ax_res1[1].set_ylabel('Excitation force [N]', color='C0')
ax_res1[1].tick_params(axis='y', labelcolor='C0')
plts = plt1 + plt2 + plt3 + plt4
ax_res1[1].legend(plts, [pl.get_label() for pl in plts], ncols=2, loc='lower center', frameon=False)
ax_res1[1].set_title('WEC heave velocities vs. wave excitation', fontweight='bold')
ax_res1[1].grid(color='0.75', linestyle='-', linewidth=0.5, axis='x')
ax_res1[1].set_xlabel('')

# Torque
pto_tdom.force.plot(
    ax=ax_res1[2],
    linestyle='solid',
    color='black',
    label='PTO torque',
)
max_tq = generator['max_torque']
rms_tq = generator['continuous_torque']
ax_res1[2].plot(
    pto_tdom.time,
    1*max_tq * np.ones(pto_tdom.time.shape),
    color='C5',
    linestyle='dotted',
    label=f'Peak torque limit',
)
ax_res1[2].plot(
    pto_tdom.time,
    -1*max_tq * np.ones(pto_tdom.time.shape),
    color='C5',
    linestyle='dotted',
)
ax_res1[2].plot(
    pto_tdom.time,
    1*rms_tq * np.ones(pto_tdom.time.shape),
    color='C9',
    linestyle='dotted',
    label=f'RMS torque threshold',
)
ax_res1[2].plot(
    pto_tdom.time,
    -1*rms_tq * np.ones(pto_tdom.time.shape),
    color='C9',
    linestyle='dotted',
)
ax_res1[2].set_ylabel('Torque [Nm] ')
ax_res1[2].legend(ncols=3, loc='lower center', frameon=False)
ax_res1[2].set_title('PTO torque response', fontweight='bold')
ax_res1[2].grid(color='0.75', linestyle='-', linewidth=0.5, axis='x')
ax_res1[2].set_xlabel('')

# Power
(pto_tdom['mech_power']).plot(ax=ax_res1[3], color='C8', label='Mech. power')
(pto_tdom['power']).plot(ax=ax_res1[3], color='C5', linestyle='dashed',
                             label="Elec. power")
ax_res1[3].legend(ncols=2, loc='lower center', frameon=False)
ax_res1[3].set_title('Power generation', fontweight='bold')
ax_res1[3].grid(color='0.75', linestyle='-', linewidth=0.5, axis='x')
ax_res1[3].set_ylabel('Power [W]')

# %% [markdown]
# We can also look at all four degrees of freedom and make sure the relationships between the forces in each direction are reasonable. We can see that the PTO and radiation are generally in phase in the heave direction, but inversely related for the spar. We also see that the mooring response is inversely propotional to the radiation forces of the spar (with a more delayed restoring response in pitch than in surge/heave), and that the mooring correctly has no effect on the float, which it doesn't connect to.

# %%
## Forces
fig_res2, ax_res2 = plt.subplots(len(influenced_dofs), 1, sharex=True, figsize=(8, 10))
for j, idof in enumerate(influenced_dofs):
    force_excitation = wec_tdom.force.sel(type=['Froude_Krylov', 'diffraction'])
    force_excitation = force_excitation.sum('type')
    force_excitation.sel(influenced_dof=idof).plot(ax=ax_res2[j], label='Excitation')
    wec_tdom.force.sel(influenced_dof=idof, type='radiation').plot(ax=ax_res2[j], label='Radiation')
    wec_tdom.force.sel(influenced_dof=idof, type='hydrostatics').plot(ax=ax_res2[j], label='Hydrostatics')
    wec_tdom.force.sel(influenced_dof=idof, type='Mooring').plot(ax=ax_res2[j], label='Mooring')
    wec_tdom.force.sel(influenced_dof=idof, type='PTO').plot(ax=ax_res2[j], label='PTO')
    ax_res2[j].set_title(f'{idof}')
    if j != len(influenced_dofs)-1:
        ax_res2[j].set_xlabel('')
    ax_res2[j].grid(color='0.75', linestyle='-', linewidth=0.5, axis='x')
handles_res2, labels_res2 = ax_res2[j].get_legend_handles_labels()
fig_res2.legend(handles_res2, labels_res2, loc=(0.105, 0.02), ncol=5)
fig_res2.suptitle('WEC Forces', fontweight='bold', y=0.93)

# %% [markdown]
# ## 2. Control co-design of the PTO sprocket sizing for maximum electrical power

# %% [markdown]
# ### Setup
# With our model working as expected, we can now iterate on this model with varying sprocket sizing to identify the optimal size. As with previous tutorials, we wrap the code from Part 1 into a function and iterate on our chosen design parameter (i.e. each key of the `sprockets` dictionary earlier corresponds to the `x` argument of `design_obj_fun`)

# %%
def design_obj_fun(x):
    global n
    n += 1

    # Unpack sprocket name
    x = x.squeeze()
    sprocket = list(sprockets.keys())[x]
    spr_rad = sprockets[sprocket]['diameter'] / 2
    spr_mass = sprockets[sprocket]['mass']
    spr_moi = sprockets[sprocket]['MOI']
    spr_des = sprockets[sprocket]['design']

    # PTO object for given sprocket
    pto = wot.pto.PTO(pto_ndof, kinematics, controller, pto_impedance(sprocket), loss, name)
    
    ## Constraints
    # Maximum stroke
    stroke_max = 0.5  # m
    def const_stroke_pto(wec, x_wec, x_opt, waves): 
        pos = pto.position(wec, x_wec, x_opt, waves, nsubsteps)
        return stroke_max - np.abs(pos.flatten())

    ## GENERATOR
    # peak torque
    radius = sprockets[sprocket]['diameter'] / 2
    def const_peak_torque_pto(wec, x_wec, x_opt, waves): 
        """Instantaneous torque must not exceed max torque Tmax - |T| >=0 
        """
        torque = pto.force(wec, x_wec, x_opt, waves, nsubsteps) / gear_ratio(radius)
        return generator['max_torque'] - np.abs(torque.flatten())

    # continuous torque
    def const_torque_pto(wec, x_wec, x_opt, waves): 
        """RMS torque must not exceed max continous torque 
            Tmax_conti - Trms >=0 """
        torque = pto.force(wec, x_wec, x_opt, waves, nsubsteps) / gear_ratio(radius)
        torque_rms = np.sqrt(np.mean(torque.flatten()**2))
        return generator['continuous_torque'] - torque_rms

    # max speed
    def const_speed_pto(wec, x_wec, x_opt, waves): 
        rot_vel = pto.velocity(wec, x_wec, x_opt, waves, nsubsteps) * gear_ratio(radius)
        return generator['max_speed'] - np.abs(rot_vel.flatten())

    ## Constraints
    constraints = [
        {'type': 'ineq', 'fun': const_stroke_pto},
        {'type': 'ineq', 'fun': const_peak_torque_pto},
        {'type': 'ineq', 'fun': const_torque_pto},
        {'type': 'ineq', 'fun': const_speed_pto},
    ]

    # additional forces
    f_add = {
        'PTO': pto.force_on_wec,
        'Mooring': mooring_force
    }

    # create WEC object
    wec = wot.WEC.from_bem(bem_data,
                           inertia_matrix=inertia,
                           hydrostatic_stiffness=hydrostatic_stiffness,
                           constraints=constraints,
                           friction=friction,
                           f_add=f_add,
    )

    # Objective function
    obj_fun = pto.average_power 

    print(
        f'\nRun {n} of {N}: Sprocket {sprocket}\n' +
        f'   Sprocket diameter: {spr_rad*2} m\n' +
        f'   Sprocket mass: {spr_mass} kg\n' +
        f'   Sprocket moment of inertia: {spr_moi} kg-m^2\n' +
        f'   Sprocket design: {spr_des}')

    results = wec.solve(
        waves['south_max_occurrence'],
        # waves['regular'], 
        obj_fun, 
        nstate_opt, 
        scale_x_wec=scale_x_wec,
        scale_x_opt=scale_x_opt,
        scale_obj=scale_obj,
    )
    print(f'Optimal average electrical power: {results.fun:.2f} W')
    return results.fun

# %% [markdown]
# Given there are only 22 sprockets, we will continue to use a brute force algorithm.

# %%
global n; n = 0 
global N; N = len(sprockets)
ranges = slice(0, N, 1),

# solve
opt_x0, opt_fval, x0s, fvals = brute(func=design_obj_fun, ranges=ranges, full_output=True, finish=None)

# %% [markdown]
# ### Results
# Comparing the results across the range of sprocket sizes, it is clear that power generation is maximized when sprocket dimensions are minimized. Thus, the 8MX-32S-36 sprocket is the best sprocket selection for LUPA for the selected wave case.
#
# The motivation to include an interchangeable sprocket in LUPA is to make it versatile across different locations and wave conditions. The optimal sprocket could be different when tested with a milder wave climate or a different mooring configuration. Try different `wave_cases` keys or modify the mooring system parameters (`init_fair_coords`, `anch_coords`, `line_ax_stiff`, and `pretension`) and see how the WEC response changes and which sprocket generates the most power.

# %%
spr_names = list(sprockets.keys())
spr_diameters = np.zeros(len(spr_names))
for i, spr in enumerate(spr_names):
    spr_diameters[i] = sprockets[spr]['diameter']

# %%
fig1, ax1 = plt.subplots()
ax1.grid()
ax1.plot(spr_diameters, fvals, 'k', zorder=0)
ax1.scatter(spr_diameters, fvals, zorder=1)
ax1.set_xlabel('Sprocket diameter [m]')
ax1.set_ylabel('Power [W]')
ax1.set_title('Design optimization results vs. sprocket diameter', fontweight='bold')
osu_sprockets = ['8MX-32S-36', '8MX-50S-36', '8MX-80S-36']
for i, spr in enumerate(spr_names):
    if spr in spr_names[opt_x0.squeeze()]:
        ax1.annotate(spr, xy=(spr_diameters[i], fvals[i]), xytext=(30, -3.5), textcoords='offset points', arrowprops=dict(arrowstyle='->', facecolor='black'))
    elif spr in osu_sprockets:
        ax1.annotate(spr, xy=(spr_diameters[i], fvals[i]), xytext=(30, -3.5), textcoords='offset points', arrowprops=dict(arrowstyle='->', facecolor='black'))
# Out:
# Text(0.5, 1.0, 'Design optimization results vs. sprocket diameter')
