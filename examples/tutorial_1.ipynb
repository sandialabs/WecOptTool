# %% [markdown]
# # Tutorial 1 - WaveBot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plots

# %%
x = np.linspace(0, 4*np.pi, 1000)

plt.figure()
plt.plot(x, np.cos(x))
